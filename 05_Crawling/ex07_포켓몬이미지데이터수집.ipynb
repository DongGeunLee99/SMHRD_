# %% [markdown]
# ### 포켓몬스터 공식 사이트에서 이미지 데이터 수집하기
# - 바탕화면에 "포켓몬도감"이라는 폴더를 생성하고
# - 이미지 데이터를 다운로드 받아서 폴더 안에 하나씩 저장해보자

# %%
import os
import time
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

import undetected_chromedriver as uc

# 이미지 경로를 받아서 파일로 변환해주는 라이브러리
from urllib.request import urlretrieve

# %%
# 바탕화면에 '포켓몬도감'이라는 폴더 생성
if os.path.isdir('C:\\Users\\smhrd\\Desktop\\포켓몬도감') is not True:
    # 포켓몬 도감 폴더를 만드는 실행문장
    os.mkdir('C:\\Users\\smhrd\\Desktop\\포켓몬도감')
    print("폴더가 생성되었습니다")
else:
    print("이미 폴더가 존재합니다")
# Out:
# 이미 폴더가 존재합니다

# %%
# 사이트 정보 가져오기
s = Service(ChromeDriverManager().install())
driver = wb.Chrome(service=s)
driver.get('https://pokemonkorea.co.kr/pokedex')

# %%
# 객체화
soup = bs(driver.page_source, 'lxml')

# %%
poke_img = soup.select('img.img-fluid')
poke_img[0].text
# img 태그는 홀태그이기 때문에 contents가 존재하지 않는다
# 이미지의 경로를 가져와서 이미지파일로 변환해줘야 한다
# Out:
# ''

# %%
#속성값 인덱싱
poke_img[0]['src']
# Out:
# 'https://data1.pokemonkorea.co.kr/newdata/pokedex/mid/000101.png'

# %%
img_list = []
for i in range(len(poke_img)):
    img_list.append(poke_img[i]['src'])

# %% [markdown]
# ### 이미지 경로를 이미지 파일로 변환하기
# - urlretrieve 라이브러리

# %%
# 이미지 파일로 저장
urlretrieve(img_list[0],'C:\\Users\\smhrd\\Desktop\\포켓몬도감\\파이리.png')
# Out:
# ('C:\\Users\\smhrd\\Desktop\\포켓몬도감\\파이리.png',
#  <http.client.HTTPMessage at 0x1c5edfa0e30>)

# %%
# 반복문을 통해 포켓몬 이미지 데이터 수집
for i in range(len(img_list)):
    urlretrieve(img_list[i],'C:\\Users\\smhrd\\Desktop\\포켓몬도감\\{}.png'.format(i))

# %%
# 스크롤 내리기
# 화면 전체를 담당하고 있는 body에게 end키로 스크롤
body = driver.find_element(By.CSS_SELECTOR, 'body')
for i in range(20):
    body.send_keys(Keys.END)
    time.sleep(1)

# %% [markdown]
# ### 이미지 크롤링

# %%
import os
import time
import pandas as pd
from bs4 import BeautifulSoup as bs
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys 
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from urllib.request import urlretrieve

if os.path.isdir('C:\\Users\\smhrd\\Desktop\\포켓몬도감') is not True:
    os.mkdir('C:\\Users\\smhrd\\Desktop\\포켓몬도감')
    print("폴더가 생성되었습니다")
else:
    print("이미 폴더가 존재합니다")

s = Service(ChromeDriverManager().install())
driver = wb.Chrome(service=s)
driver.get('https://pokemonkorea.co.kr/pokedex')


# 스크롤 전체 높이 저장
body = driver.find_element(By.CSS_SELECTOR, 'section.sect')

last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # 맨 밑까지 스크롤 내리기
    body.send_keys(Keys.END)

    # 페이지 로드 되는 것 기다리기
    time.sleep(1)

    # 스크롤 전체 높이와 지금까지 내린 스크롤 높이를 비교하는 코드
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:  # 만약 현재 높이와 스크롤 전체 높이가 같아지면
        break    # 반복문을 빠져나가주세요
    last_height = new_height


soup = bs(driver.page_source, 'lxml')
poke_img = soup.select('img.img-fluid')

img_list = []
for i in range(len(poke_img)):
    img_list.append(poke_img[i]['src'])

a = soup.select('div.bx-txt')
n =[]

for i in range(len(a)):
    aa = a[i].text.strip()
    n.append(aa[(aa.find(' ')+1):aa.find('\n')])

for i in range(len(img_list)):
    urlretrieve(img_list[i],'C:\\Users\\smhrd\\Desktop\\포켓몬도감\\{}.png'.format(n[i]))
# Out:
# 이미 폴더가 존재합니다
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Cell In[2], line 30
#      26 last_height = driver.execute_script("return document.body.scrollHeight")
#      28 while True:
#      29     # 맨 밑까지 스크롤 내리기
# ---> 30     body.send_keys(Keys.END)
#      32     # 페이지 로드 되는 것 기다리기
#      33     time.sleep(1)
#
# File c:\Users\smhrd\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:301, in WebElement.send_keys(self, *value)
#     298             remote_files.append(self._upload(file))
#     299         value = tuple("\n".join(remote_files))
# --> 301 self._execute(
#     302     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     303 )
#
# File c:\Users\smhrd\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:570, in WebElement._execute(self, command, params)
#     568     params = {}
#     569 params["id"] = self._id
# --> 570 return self._parent.execute(command, params)
#
# File c:\Users\smhrd\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response["value"] = self._unwrap_value(response.get("value", None))
#     431     return response
#
# File c:\Users\smhrd\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=133.0.6943.142)
# Stacktrace:
# 	GetHandleVerifier [0x00570B43+25139]
# 	(No symbol) [0x005013F4]
# 	(No symbol) [0x003E0340]
# 	(No symbol) [0x00422DE9]
# 	(No symbol) [0x00421BFD]
# 	(No symbol) [0x0044CFCC]
# 	(No symbol) [0x0041D9A4]
# 	(No symbol) [0x0044D244]
# 	(No symbol) [0x0046E778]
# 	(No symbol) [0x0044CDC6]
# 	(No symbol) [0x0041BDE9]
# 	(No symbol) [0x0041D124]
# 	GetHandleVerifier [0x00874373+3185251]
# 	GetHandleVerifier [0x0089291A+3309578]
# 	GetHandleVerifier [0x0088CF42+3286578]
# 	GetHandleVerifier [0x00607AE0+643536]
# 	(No symbol) [0x0050A20D]
# 	(No symbol) [0x005070B8]
# 	(No symbol) [0x00507257]
# 	(No symbol) [0x004F9E00]
# 	BaseThreadInitThunk [0x7513FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x772382AE+286]
# 	RtlGetAppContainerNamedObjectPath [0x7723827E+238]

# %%
# 스크롤 끝까지 내리는 코드

# 스크롤 전체 높이 저장
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # 맨 밑까지 스크롤 내리기
    body.send_keys(Keys.END) 

    # 페이지 로드 되는 것 기다리기
    time.sleep(1)

    # 스크롤 전체 높이와 지금까지 내린 스크롤 높이를 비교하는 코드
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:  # 만약 현재 높이와 스크롤 전체 높이가 같아지면
        break    # 반복문을 빠져나가주세요
    last_height = new_height
# Out:
# ['이상해씨',
#  '이상해풀',
#  '이상해꽃',
#  '메가이상해꽃',
#  '이상해꽃',
#  '파이리',
#  '리자드',
#  '리자몽',
#  '메가리자몽X',
#  '메가리자몽Y',
#  '리자몽',
#  '꼬부기',
#  '어니부기',
#  '거북왕',
#  '메가거북왕',
#  '거북왕',
#  '캐터피',
#  '단데기',
#  '버터플',
#  '버터플',
#  '뿔충이',
#  '딱충이',
#  '독침붕',
#  '메가독침붕',
#  '구구',
#  '피죤',
#  '피죤투',
#  '메가피죤투',
#  '꼬렛',
#  '꼬렛',
#  '레트라',
#  '레트라',
#  '깨비참',
#  '깨비드릴조',
#  '아보',
#  '아보크',
#  '피카츄',
#  '피카츄',
#  '라이츄',
#  '라이츄',
#  '모래두지',
#  '모래두지',
#  '고지',
#  '고지',
#  '니드런♀',
#  '니드리나',
#  '니드퀸',
#  '니드런♂',
#  '니드리노',
#  '니드킹',
#  '삐삐',
#  '픽시',
#  '식스테일',
#  '식스테일',
#  '나인테일',
#  '나인테일',
#  '푸린',
#  '푸크린',
#  '주뱃',
#  '골뱃',
#  '뚜벅쵸',
#  '냄새꼬',
#  '라플레시아',
#  '파라스',
#  '파라섹트',
#  '콘팡',
#  '도나리',
#  '디그다',
#  '디그다',
#  '닥트리오',
#  '닥트리오',
#  '나옹',
#  '나옹',
#  '나옹',
#  '나옹',
#  '페르시온',
#  '페르시온',
#  '고라파덕',
#  '골덕',
#  '망키',
#  '성원숭',
#  '가디',
#  '가디',
#  '윈디',
#  '윈디',
#  '발챙이',
#  '슈륙챙이',
#  '강챙이',
#  '캐이시',
#  '윤겔라',
#  '후딘',
#  '메가후딘',
#  '알통몬',
#  '근육몬',
#  '괴력몬',
#  '괴력몬',
#  '모다피',
#  '우츠동',
#  '우츠보트',
#  '왕눈해',
#  '독파리',
#  '꼬마돌',
#  '꼬마돌',
#  '데구리',
#  '데구리',
#  '딱구리',
#  '딱구리',
#  '포니타',
#  '포니타',
#  '날쌩마',
#  '날쌩마',
#  '야돈',
#  '야돈',
#  '야도란',
#  '야도란',
#  '메가야도란',
#  '코일',
#  '레어코일',
#  '파오리',
#  '파오리',
#  '두두',
#  '두트리오',
#  '쥬쥬',
#  '쥬레곤',
#  '질퍽이',
#  '질퍽이',
#  '질뻐기',
#  '질뻐기',
#  '셀러',
#  '파르셀',
#  '고오스',
#  '고우스트',
#  '팬텀',
#  '메가팬텀',
#  '팬텀',
#  '롱스톤',
#  '슬리프',
#  '슬리퍼',
#  '크랩',
#  '킹크랩',
#  '킹크랩',
#  '찌리리공',
#  '찌리리공',
#  '붐볼',
#  '붐볼',
#  '아라리',
#  '나시',
#  '나시',
#  '탕구리',
#  '텅구리',
#  '텅구리',
#  '시라소몬',
#  '홍수몬',
#  '내루미',
#  '또가스',
#  '또도가스',
#  '또도가스',
#  '뿔카노',
#  '코뿌리',
#  '럭키',
#  '덩쿠리',
#  '캥카',
#  '메가캥카',
#  '쏘드라',
#  '시드라',
#  '콘치',
#  '왕콘치',
#  '별가사리',
#  '아쿠스타',
#  '마임맨',
#  '마임맨',
#  '스라크',
#  '루주라',
#  '에레브',
#  '마그마',
#  '쁘사이저',
#  '메가쁘사이저',
#  '켄타로스',
#  '켄타로스',
#  '켄타로스',
#  '켄타로스',
#  '잉어킹',
#  '갸라도스',
#  '메가갸라도스',
#  '라프라스',
#  '라프라스',
#  '메타몽',
#  '이브이',
#  '이브이',
#  '샤미드',
#  '쥬피썬더',
#  '부스터',
#  '폴리곤',
#  '암나이트',
#  '암스타',
#  '투구',
#  '투구푸스',
#  '프테라',
#  '메가프테라',
#  '잠만보',
#  '잠만보',
#  '프리져',
#  '프리져',
#  '썬더',
#  '썬더',
#  '파이어',
#  '파이어',
#  '미뇽',
#  '신뇽',
#  '망나뇽',
#  '뮤츠',
#  '메가뮤츠X',
#  '메가뮤츠Y',
#  '뮤',
#  '치코리타',
#  '베이리프',
#  '메가니움',
#  '브케인',
#  '마그케인',
#  '블레이범',
#  '블레이범',
#  '리아코',
#  '엘리게이',
#  '장크로다일',
#  '꼬리선',
#  '다꼬리',
#  '부우부',
#  '야부엉',
#  '레디바',
#  '레디안',
#  '페이검',
#  '아리아도스',
#  '크로뱃',
#  '초라기',
#  '랜턴',
#  '피츄',
#  '삐',
#  '푸푸린',
#  '토게피',
#  '토게틱',
#  '네이티',
#  '네이티오',
#  '메리프',
#  '보송송',
#  '전룡',
#  '메가전룡',
#  '아르코',
#  '마릴',
#  '마릴리',
#  '꼬지모',
#  '왕구리',
#  '통통코',
#  '두코',
#  '솜솜코',
#  '에이팜',
#  '해너츠',
#  '해루미',
#  '왕자리',
#  '우파',
#  '우파',
#  '누오',
#  '에브이',
#  '블래키',
#  '니로우',
#  '야도킹',
#  '야도킹',
#  '무우마',
#  '안농',
#  '마자용',
#  '키링키',
#  '피콘',
#  '쏘콘',
#  '노고치',
#  '글라이거',
#  '강철톤',
#  '메가강철톤',
#  '블루',
#  '그랑블루',
#  '침바루',
#  '침바루',
#  '핫삼',
#  '메가핫삼',
#  '단단지',
#  '헤라크로스',
#  '메가헤라크로스',
#  '포푸니',
#  '포푸니',
#  '깜지곰',
#  '링곰',
#  '마그마그',
#  '마그카르고',
#  '꾸꾸리',
#  '메꾸리',
#  '코산호',
#  '코산호',
#  '총어',
#  '대포무노',
#  '딜리버드',
#  '만타인',
#  '무장조',
#  '델빌',
#  '헬가',
#  '메가헬가',
#  '킹드라',
#  '코코리',
#  '코리갑',
#  '폴리곤2',
#  '노라키',
#  '루브도',
#  '배루키',
#  '카포에라',
#  '뽀뽀라',
#  '에레키드',
#  '마그비',
#  '밀탱크',
#  '해피너스',
#  '라이코',
#  '앤테이',
#  '스이쿤',
#  '애버라스',
#  '데기라스',
#  '마기라스',
#  '메가마기라스',
#  '루기아',
#  '칠색조',
#  '세레비',
#  '나무지기',
#  '나무돌이',
#  '나무킹',
#  '메가나무킹',
#  '아차모',
#  '영치코',
#  '번치코',
#  '메가번치코',
#  '물짱이',
#  '늪짱이',
#  '대짱이',
#  '메가대짱이',
#  '포챠나',
#  '그라에나',
#  '지그제구리',
#  '지그제구리',
#  '직구리',
#  '직구리',
#  '개무소',
#  '실쿤',
#  '뷰티플라이',
#  '카스쿤',
#  '독케일',
#  '연꽃몬',
#  '로토스',
#  '로파파',
#  '도토링',
#  '잎새코',
#  '다탱구',
#  '테일로',
#  '스왈로',
#  '갈모매',
#  '패리퍼',
#  '랄토스',
#  '킬리아',
#  '가디안',
#  '메가가디안',
#  '비구술',
#  '비나방',
#  '버섯꼬',
#  '버섯모',
#  '게을로',
#  '발바로',
#  '게을킹',
#  '토중몬',
#  '아이스크',
#  '껍질몬',
#  '소곤룡',
#  '노공룡',
#  '폭음룡',
#  '마크탕',
#  '하리뭉']
